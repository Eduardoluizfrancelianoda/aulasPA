# %% [markdown]
# <a href="https://colab.research.google.com/github/Eduardoluizfrancelianoda/aulasPA/blob/main/exercicios_fluxograma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **exercicio** **1**

# %%
dolar= float(input("cotação do dolar= "))
valor= float(input("o valor que voce quer converter em dolares= "))
valoremdolares= valor/dolar
print(valoremdolares, "dolares")
# Out:
# cotação do dolar= 5
# o valor que voce quer converter em dolares= 2.55
# 0.51 dolares

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **exercicio** **2**

# %%
n1= float(input("primeiro numero = "))
n2= float(input("segundo numero = "))
n3= float(input("terceiro numero = "))
n4= float(input("quarto numero = "))
total_soma= n1*n1+n2*n2+n3*n3+n4*n4
round(total_soma)
# Out:
# primeiro numero = 2
# segundo numero = 4
# terceiro numero = 5
# quarto numero = 6
# 81

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **exercicio** **3**

# %%
preco_unitario= float(input("insira o preço unitario "))
quantidade_vendida= float(input("insira a quantidade de peças vendidas "))
totaldedinheiro= preco_unitario*quantidade_vendida
totaldedinheiro* 0.5
# Out:
# insira o preço unitario 2.5
# insira a quantidade de peças vendidas 200
# 25.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **exercicio 4**

# %%
custodefabrica= float(input("insira o custo de fabrica "))
impostos= custodefabrica*0.45
custo_com_impostos= custodefabrica+impostos
distribuicao= custo_com_impostos*0.28
total= custo_com_impostos+distribuicao
total
# Out:
# insira o custo de fabrica 25000
# 46400.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **exercicio 5**

# %%
horas= int(input("horas "))
minutos= int(input("minutos "))
total_minutos= horas*60+minutos
total_segundos=total_minutos*60
print(horas, "horas e",minutos, "minutos equivalem a" ,total_segundos, "segundos")
# Out:
# horas 4
# minutos 25
# 4 horas e 25 minutos equivalem a 15900 segundos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **exercicio 6**

# %%
horas_trabalhadas= int(input("horas trabalhadas "))
minutos_trabalhados=int(input("minutos trabalhados "))
valor_por_hora= float(input("valor por hora"))
total_horas= horas_trabalhadas+minutos_trabalhados/60
salario_normal= total_horas*valor_por_hora
salario_extra=salario_normal*0.7
salario_total= salario_normal+salario_extra
round(salario_total,2)
# Out:
# horas trabalhadas 15
# minutos trabalhados 45
# valor por hora25
# 669.38

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **exercicio 7**

# %%
quilometros= float(input("quantidade de quilometros "))
consumo= float(input("consumo de gasolina "))
preco_gasolina= float(input("preco medio da gasolina "))

litros_necessarios= quilometros/consumo
custo_total= litros_necessarios*preco_gasolina
print(custo_total,custo_total*2)
# Out:
# quantidade de quilometros 420
# consumo de gasolina 10
# preco medio da gasolina 4.20
# 176.4 352.8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **exercicio 8**

# %%
percurso= float(input("digite o percurso percorrido em km" ))
tempo= float(input("digite o tempo gasto" ))
velocidade_media= percurso/tempo
print("a velocidade media do carro foi de", velocidade_media,"km/h")
# Out:
# digite o percurso percorrido em km150
# digite o tempo gasto1.13
# a velocidade media do carro foi de 132.7433628318584 km/h

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
